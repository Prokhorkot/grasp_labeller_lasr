# %%
import h5py
from pathlib import Path

# %%
iteration_path = "/mnt/d/prokhor_projects/grasp_labeller_lasr/dataset/black_table_clock/20260502_172000.h5"

# %%
PHASE_DATA_RELATIVE_PATH = Path("grasp/grasp_phases.csv")

# %%
with h5py.File(iteration_path, "r") as h5_file:
    for key in h5_file:
        print(h5_file[str(key / PHASE_DATA_RELATIVE_PATH)])
    # print(h5_file[str(PHASE_DATA_RELATIVE_PATH)])
# Out:
# <HDF5 dataset "grasp_phases.csv": shape (4,), type "|V24">
